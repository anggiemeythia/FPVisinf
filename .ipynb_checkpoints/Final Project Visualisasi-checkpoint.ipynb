# %%
import pandas as pd
import matplotlib.pyplot as plt


pd.set_option('display.width', 5000) 
pd.set_option('display.max_columns', 60)

plt.rcParams['figure.figsize'] = (15, 5)

# %%
#Anggie Disini

# %%
gakinSBY = pd.read_csv('data/data.csv')
gakinSBY[:10]
# Out:
#    Unnamed: 0           NIK              tgl_lhr jenis_klmn       pkrjn_descrip        pendidikan_descrip           hubkel      kecamatan
# 0           0  3.578020e+15  1978-07-27 00:00:00          P    KARYAWAN HONORER            SLTA/SEDERAJAT            ISTRI       Wonocolo
# 1           1  3.578010e+15  1988-04-25 00:00:00          L     KARYAWAN SWASTA            SLTA/SEDERAJAT  KEPALA KELUARGA  Karang Pilang
# 2           2  3.578210e+15  1977-03-16 00:00:00          L  BURUH HARIAN LEPAS            SLTP/SEDERAJAT  KEPALA KELUARGA    Dukuh Pakis
# 3           3  3.578010e+15  1995-12-19 00:00:00          L   PELAJAR/MAHASISWA            SLTA/SEDERAJAT             ANAK  Karang Pilang
# 4           4  3.578020e+15  1979-02-27 00:00:00          P     KARYAWAN SWASTA            SLTA/SEDERAJAT            ISTRI       Wonocolo
# 5           5  3.201050e+15  1984-08-15 00:00:00          P          WIRASWASTA            SLTP/SEDERAJAT            ISTRI            NaN
# 6           6  3.578010e+15  1978-11-04 00:00:00          L          WIRASWASTA       DIPLOMA IV/STRATA I  KEPALA KELUARGA  Karang Pilang
# 7           7  3.316150e+15  1998-08-25 00:00:00          L   PELAJAR/MAHASISWA        TAMAT SD/SEDERAJAT             ANAK            NaN
# 8           8  3.578010e+15  2004-03-26 00:00:00          L   PELAJAR/MAHASISWA  BELUM TAMAT SD/SEDERAJAT             ANAK  Karang Pilang
# 9           9  3.578010e+15  1975-06-13 00:00:00          L     KARYAWAN SWASTA            SLTP/SEDERAJAT  KEPALA KELUARGA  Karang Pilang

# %%
#Insight Muhammad Khotib
#1. Istri yang tidak bekerja tiap kecamatan
is_Istri = gakinSBY.hubkel=='ISTRI'
isTidakKerja = (dfIstriRT['pkrjn_descrip']=='BELUM/TIDAK BEKERJA') | (dfIstriRT['pkrjn_descrip']=='MENGURUS RUMAH TANGGA')
dfIstri = gakinSBY[is_Istri][isTidakKerja]['kecamatan'].value_counts()
dfIstri.plot(kind='bar')

# %%
#2. Jumlah warga (bukan anak) yang tidak tamat SD
is_Suami_Istri = (gakinSBY['hubkel'] == 'KEPALA KELUARGA') | (gakinSBY['hubkel'] == 'ISTRI')
is_tidak_tamat_sd = (gakinSBY['pendidikan_descrip'] == 'TIDAK/BLM SEKOLAH') | (gakinSBY['pendidikan_descrip'] == 'BELUM TAMAT SD/SEDERAJAT')
dfDua = gakinSBY[is_Suami_Istri][is_tidak_tamat_sd]['kecamatan'].value_counts()
dfDua.plot(kind='bar')
# Out:
# c:\python37-32\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
#3. Persentase istri yang tidak bekerja tetapi pendidikan SLTA
is_tidak_slta = gakinSBY['pendidikan_descrip'] == 'SLTA/SEDERAJAT'
gakinSBY[is_Istri][isTidakKerja][is_tidak_slta]['kecamatan'].value_counts().plot(kind='bar')
# Out:
# c:\python37-32\lib\site-packages\ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
#4. Tingkat pendidikan paling dominan
sizes = gakinSBY['pendidikan_descrip'].value_counts().plot(kind='bar')

# %%
#5. Persentase istri yang bekerja
isKerja = ~isTidakKerja
istriKerja = len(gakinSBY[is_Istri][isKerja].index)
istriUnKerja = len(gakinSBY[is_Istri][isTidakKerja].index)

labels = 'istri yang tidak bekerja','Istri yang bekerja'
sizes = [istriKerja, istriUnKerja]
explode = (0.1, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal') 
plt.show()

# %%
#6. Persentase pendidikan kepala keluarga
isKepalaKeluarga = (gakinSBY['hubkel'] == 'KEPALA KELUARGA')
isS1 = gakinSBY[isKepalaKeluarga]['pendidikan_descrip']=='DIPLOMA IV/STRATA I'
dfs1 = gkinSBY[isS1]
dfs1.loc[dfs1['pendidikan_descrip']=='DIPLOMA IV/STRATA I', 'pendidikan_descrip'] = 'Lebih dari SLTA'

#.value_counts().plot(kind='pie')
# Out:
# c:\python37-32\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-132-52815912a5c8> in <module>
#       3 isS1 = gakinSBY[isKepalaKeluarga]['pendidikan_descrip']=='DIPLOMA IV/STRATA I'
#       4
# ----> 5 gakinSBY[isS1].loc[gakinSBY['pendidikan_descrip']=='DIPLOMA IV/STRATA I', 'pendidikan_descrip'] = 'Lebih dari SLTA'
#       6
#       7 #.value_counts().plot(kind='pie')
#
# c:\python37-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2916         # Do we have a (boolean) 1d indexer?
#    2917         if com.is_bool_indexer(key):
# -> 2918             return self._getitem_bool_array(key)
#    2919
#    2920         # We are left with two options: a single key, and a collection of keys,
#
# c:\python37-32\lib\site-packages\pandas\core\frame.py in _getitem_bool_array(self, key)
#    2965         # check_bool_indexer will throw exception if Series key cannot
#    2966         # be reindexed to match DataFrame rows
# -> 2967         key = check_bool_indexer(self.index, key)
#    2968         indexer = key.nonzero()[0]
#    2969         return self._take(indexer, axis=0)
#
# c:\python37-32\lib\site-packages\pandas\core\indexing.py in check_bool_indexer(ax, key)
#    2484         mask = isna(result._values)
#    2485         if mask.any():
# -> 2486             raise IndexingError('Unalignable boolean Series provided as '
#    2487                                 'indexer (index of the boolean Series and of '
#    2488                                 'the indexed object do not match')
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match

# %%
#Gamal Disini
